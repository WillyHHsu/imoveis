# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.float_format = '{:,.2f}'.format

# %%
pd.read_csv('data/processed/test.csv.gzip',compression='gzip', sep=';')
# Out:
#        usableAreas                                        description  \
# 0            47.00  Apartamentos de 1 dormitório na Rua Bela Cintr...
# 1            55.00  Ótima localização, próximo ao shopping Central...
# 2            92.00  Apartamento maravilhoso com ampla sala ( abriu...
# 3           145.00  Apartamento residencial à venda, Brooklin Paul...
# 4            76.00                                                NaN
# ...            ...                                                ...
# 16031        64.00  Apartamento à venda com 63 m², 2 dormitórios e...
# 16032        48.00  Lindo Com 1 Vaga De Garagem Acabamento De Prim...
# 16033        72.00  Belo apartamento com 3 dormitórios repleto de ...
# 16034        85.00  Apartamento originalmente de 3 quartos e 1 ban...
# 16035       230.00  O Apartamento tem 230 metros quadrados no bair...
#
#                                                    title  \
# 0                                Apartamento Bela Cintra
# ...
